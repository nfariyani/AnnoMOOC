# %% [markdown]
# # Load Dataset

# %%
import pandas as pd
import numpy as np
import pickle

# %%
train_df = pd.read_csv("data/dataset_mooc_label.csv")
train_df.head()
# Out:
#                                              kalimat type
# 0  Algorithm and Object Oriented Programming Methods   nm
# 1  Mata kuliah algoritma dan metode object orient...   dm
# 2  CP 1: menggunakan sintaks dan fungsi di dalam ...   cp
# 3  1. Pengertian Algoritma dan Pemrograman; Perbe...   pb
# 4                                         Basis Data   nm

# %%
label = train_df['type'].unique()
label_to_id = {}
assign_id = 0
for lbl in label:
    label_to_id[lbl] = assign_id
    assign_id += 1  ## Get a new id for label
    
##  Print the dictionary created
for key, values in label_to_id.items():
    print (key, values)
# Out:
# nm 0
# dm 1
# cp 2
# pb 3

# %%
## convert the labels to id --> So when we predict the result humans can understand

id_to_label = {v: k for k, v in label_to_id.items()}
for key, values in id_to_label.items():
    print (key, values)
# Out:
# 0 nm
# 1 dm
# 2 cp
# 3 pb

# %%
## Add a new column to pandas dataframe, with the author name mapping
def get_label_id(label):
    return label_to_id[label]

train_df['label_id'] = train_df['type'].map(get_label_id)

# %%
kalimat = train_df["kalimat"].values
kalimat
# Out:
# array(['Algorithm and Object Oriented Programming Methods',
#        'Mata kuliah algoritma dan metode object oriented programming memuat konsep-konsep dasar dalam membuat algoritma dan pemrograman yang berorientasi object dengan menggunakan bahasa C++. Fitur utamanya adalah element dasar dalam c++, input output stream, struktur data, control structures, fungsi, algoritma pengurutan data, algoritma pencarian, file stream. inheritance, polymorphism dan generic programming.',
#        'CP 1: menggunakan sintaks dan fungsi di dalam bahasa C++', ...,
#        'algoritma terdistribusi yang andal bagian 1',
#        'kursus ini adalah kursus pertama dalam rangkaian dua. kedua kursus memberikan landasan yang kuat di bidang komputasi terdistribusi yang andal termasuk model hasil konsep utama dan algoritma di lapangan. ntoday global it infrastructure adalah sistem terdistribusi dari internet ke pusat data komputasi awan yang menjadi bahan bakar revolusi layanan global saat ini. di inti layanan ini Anda menemukan algoritma terdistribusi. Algoritma ini berjalan di banyak komputer dan berkomunikasi hanya dengan mengirim dan menerima pesan. sangat penting bagi layanan yang diimplementasikan untuk terus bekerja 24 7 bahkan jika beberapa komputer gagal atau beberapa pesan hilang dalam perjalanan. ini adalah subjek algoritma terdistribusi yang andal dalam ilmu komputer. nid2203.1x mencakup model algoritma terdistribusi berdasarkan spesifikasi input automata spesifikasi abstraksi toleran kesalahan dan detektor kegagalan abstraksi terdistribusi khusus dan algoritma toleransi kesalahan termasuk penyiaran terpercaya dan penyimpan nilai kunci penyebab store dan konsistensi model konsensus nilai tunggal dan algoritma paxos. untuk menyelesaikan kursus dengan siswa kelas 100 penuh diminta untuk menjawab kuis bergradasi yang disediakan setiap minggu serta tugas pemrograman.',
#        'event driven concurrent programming dari distributed algorithm n model tformal dari asynchronous systems menggunakan input output automata failure detectors dan ekuivalensi antara berbagai abstraksi yang terdistribusi nspesifikasi dan algoritma untuk penyiaran perintah yang dapat diandalkan dan kausal distributed shared memory dan konsistensi model single value consensus dan konsensus terkait algoritma termasuk paxos. n'],
#       dtype=object)

# %%
train_df
# Out:
#                                                 kalimat type  label_id
# 0     Algorithm and Object Oriented Programming Methods   nm         0
# 1     Mata kuliah algoritma dan metode object orient...   dm         1
# 2     CP 1: menggunakan sintaks dan fungsi di dalam ...   cp         2
# 3     1. Pengertian Algoritma dan Pemrograman; Perbe...   pb         3
# 4                                            Basis Data   nm         0
# 5     Mata kuliah ini menjelaskan tentang konsep dan...   dm         1
# 6     Konsep Basis Data   Objek Basis Data Relasiona...   pb         3
# 7     data center management menggunakan docker cont...   nm         0
# 8     process isolation diperlukan dalam rangka memb...   dm         1
# 9     1. Siswa mampu memahami cara kerja docker cont...   cp         2
# 10    1. instalasi docker2. docker-compose3. pengelo...   pb         3
# 11                           Interaksi Manusia Komputer   nm         0
# 12    Kuliah ini memberikan dasar-dasar yang dibutuh...   dm         1
# 13    Setelah mengikuti kuliah ini siswa dapat menje...   cp         2
# 14    Pokok bahasan perkuliahan terdiri dari: ·     ...   pb         3
# 15                                    Jaringan Komputer   nm         0
# 16    Mata kuliah Jaringan Komputer merupakan mata k...   dm         1
# 17    CP-01: Mampu menjelaskan dan menggambarkan kon...   cp         2
# 18    Pengantar Jaringan Komputer. Model Referensi O...   pb         3
# 19                                     Machine Learning   nm         0
# 20    Memahami keterhubungan (relationships) dan ket...   dm         1
# 21            Manajemen Keamanan Informasi dan Internet   nm         0
# 22    Sejalan dengan besarnya manfaat yang diberikan...   dm         1
# 23    Fenomena Keamanan Informasi dan Internet   Hac...   pb         3
# 24    Manajemen Organisasi Teknologi Informasi Korpo...   nm         0
# 25    Dalam konteks perusahaan, pada akhirnya sumber...   dm         1
# 26    PERSPEKTIF UTAMA SISTEM ORGANISASI   PENGELOLA...   pb         3
# 27                     Manajemen Proyek Perangkat Lunak   nm         0
# 28    Melalui mata kuliah ini Mahasiswa mampu memaha...   dm         1
# 29    Mahasiswa mampu memahami teknik manajemen proy...   cp         2
# ...                                                 ...  ...       ...
# 1106  rekayasa perangkat lunak terdistribusi secara ...   nm         0
# 1107  rekayasa perangkat lunak beroperasi lebih seri...   dm         1
# 1108  untuk memahami konstruksi utama teori rekayasa...   cp         2
# 1109               ilmu informasi kuantum saya bagian 3   nm         0
# 1110  kursus ini adalah bagian terakhir dari tiga se...   dm         1
# 1111  model formal untuk kebisingan kuantum dan salu...   cp         2
# 1112  dasar pemikiran komputasi data sains dengan py...   nm         0
# 1113  kita hidup di era akses data yang belum pernah...   dm         1
# 1114  bagaimana menggunakan komputasi untuk membantu...   cp         2
# 1115  komputasi mobile dengan prinsip-prinsip penemu...   nm         0
# 1116  belajar untuk menggunakan penemu aplikasi alat...   dm         1
# 1117  bagaimana merancang dan membuat aplikasi selul...   cp         2
# 1118  informatika kesehatan global untuk meningkatka...   nm         0
# 1119  penyakit tidak memiliki rasa hormat untuk perb...   dm         1
# 1120  beban kesehatan global n merancang pemikiran n...   cp         2
# 1121               ilmu informasi kuantum saya bagian 1   nm         0
# 1122  kursus ini adalah bagian dari tiga seri kursus...   dm         1
# 1123  mekanika kuantum pengukuran kuantum perhitunga...   cp         2
# 1124  keindahan dan sukacita komputasi prinsip-prins...   nm         0
# 1125  temukan ide-ide besar dan praktik berpikir dal...   dm         1
# 1126  dasar-dasar pemrograman komputer menggunakan s...   cp         2
# 1127                                kriptografi kuantum   nm         0
# 1128  bagaimana Anda bisa menceritakan rahasia ketik...   dm         1
# 1129  ide-ide dasar dari kriptografi kuantum konsep ...   cp         2
# 1130  pemrograman untuk semua orang pengantar pemrog...   nm         0
# 1131  kursus ini adalah bagian dari gfa akademi maha...   dm         1
# 1132  apa yang seorang ilmuwan komputer tidak melaku...   cp         2
# 1133        algoritma terdistribusi yang andal bagian 1   nm         0
# 1134  kursus ini adalah kursus pertama dalam rangkai...   dm         1
# 1135  event driven concurrent programming dari distr...   cp         2
#
# [1136 rows x 3 columns]

# %% [markdown]
# # Preproses Dataset

# %%
import json
from tqdm import tqdm_notebook as tqdm
from polyglot.downloader import downloader
from polyglot.text import Text
import re

#download data pos tagging
downloader.download("embeddings2.id")
downloader.download("pos2.id")

#membersihkan data text
def cleanText (text):
    textClear = re.sub ('[^ a-zA-Z]', ' ',text.lower())
    return textClear

def getPosTag(tagText):
    jmlKata = len(tagText.split())
    propn = 0
    takso = 0
    noun = 0
    subyek = 0
    posTag=Text(tagText, hint_language_code='id')

    #menambahkan rule
    listTag=['NOUN', 'PROPN']
    bloom = open("data/taksonomi.txt").read().splitlines()
    subjek = open("data/subjek.txt").read().splitlines()
    
    for kata in posTag.pos_tags:
        if kata[0] in subjek:
            subyek = 1
        if kata[0] in bloom:
            takso += 1
        if kata[1] in listTag:
            if kata[1] == 'PROPN':
                propn += 1
            if kata[1] == 'NOUN':
                noun += 1
    propn = (propn/jmlKata)
    takso = (takso/jmlKata)
    noun = (noun/jmlKata)
    return propn, takso, noun, subyek, jmlKata

#open file
deskr=[]

for index, desk in tqdm(enumerate(kalimat)):
#     print(desk)
    ct={}   
    ct['kalimat'] = cleanText(desk)
    ct['propn'],ct['takso'], ct['noun'], ct['subyek'], ct['jk']=getPosTag(ct['kalimat'])
    ct['label']=train_df["label_id"][index]
    deskr.append(ct)
# Out:
# [polyglot_data] Downloading package embeddings2.id to C:\Users\Purina
# [polyglot_data]     QA\AppData\Roaming\polyglot_data...
# [polyglot_data]   Package embeddings2.id is already up-to-date!
# [polyglot_data] Downloading package pos2.id to C:\Users\Purina
# [polyglot_data]     QA\AppData\Roaming\polyglot_data...
# [polyglot_data]   Package pos2.id is already up-to-date!
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))

# %%
#tanpa fitur tfidf
deskr_p=pd.DataFrame(deskr)
print(deskr_p.drop(columns=['kalimat']))
# Out:
#        jk  label      noun     propn  subyek     takso
# 0       6      0  0.666667  0.166667       0  0.000000
# 1      51      1  0.666667  0.019608       1  0.019608
# 2       9      2  0.333333  0.222222       0  0.222222
# 3      52      3  0.653846  0.115385       0  0.000000
# 4       2      0  1.000000  0.000000       0  0.000000
appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   """Entry point for launching an IPython kernel.
# c:\users\purina qa\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf = TfidfVectorizer(sublinear_tf=True, min_df=5, norm='l2', encoding='latin-1', ngram_range=(1, 2), max_features=150)
tv = tfidf.fit_transform(kalimat)
with open('data/model/vectorizer.pkl', 'wb') as tvc:
    pickle.dump(tfidf, tvc)
features = tv.toarray()
labels = label
features.shape
featureName=tfidf.get_feature_names()

# %%
tfidf
# Out:
# TfidfVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.float64'>, encoding='latin-1', input='content',
#         lowercase=True, max_df=1.0, max_features=150, min_df=5,
#         ngram_range=(1, 2), norm='l2', preprocessor=None, smooth_idf=True,
#         stop_words=None, strip_accents=None, sublinear_tf=True,
#         token_pattern='(?u)\\b\\w\\w+\\b', tokenizer=None, use_idf=True,
#         vocabulary=None)

# %%
len(features[:,0])
# Out:
# 1136

# %%
#menambah fitur tfidf
for index,ftr in enumerate(featureName):
    deskr_p[ftr]=features[:,index]

# %%
deskr_p.to_csv('data/fitur.csv')

# %%
deskr_p
# Out:
#        jk                                            kalimat  label      noun  \
# 0       6  algorithm and object oriented programming methods      0  0.666667
# 1      51  mata kuliah algoritma dan metode object orient...      1  0.666667
# 2       9  cp    menggunakan sintaks dan fungsi di dalam ...      2  0.333333
# 3      52     pengertian algoritma dan pemrograman  perbe...      3  0.653846
# 4       2                                         basis data      0  1.000000
# 5      86  mata kuliah ini menjelaskan tentang konsep dan...      1  0.581395
# 6      24  konsep basis data   objek basis data relasiona...      3  0.833333
# 7       6  data center management menggunakan docker cont...      0  0.166667
# 8      44  process isolation diperlukan dalam rangka memb...      1  0.431818
# 9       7     siswa mampu memahami cara kerja docker cont...      2  0.428571
# 10      6     instalasi docker   docker compose   pengelo...      3  0.500000
# 11      3                         interaksi manusia komputer      0  1.000000
# 12     71  kuliah ini memberikan dasar dasar yang dibutuh...      1  0.464789
# 13     21  setelah mengikuti kuliah ini siswa dapat menje...      2  0.476190
# 14     52  pokok bahasan perkuliahan terdiri dari        ...      3  0.673077
# 15      2                                  jaringan komputer      0  1.000000
# 16     95  mata kuliah jaringan komputer merupakan mata k...      1  0.642105
# 17    131  cp     mampu menjelaskan dan menggambarkan kon...      2  0.465649
# 18     48  pengantar jaringan komputer  model referensi o...      3  0.833333
# 19      2                                   machine learning      0  0.000000
# 20    108  memahami keterhubungan  relationships  dan ket...      1  0.379630
# 21      5          manajemen keamanan informasi dan internet      0  0.800000
# 22    105  sejalan dengan besarnya manfaat yang diberikan...      1  0.409524
# 23     23  fenomena keamanan informasi dan internet   hac...      3  0.695652
# 24      5  manajemen organisasi teknologi informasi korpo...      0  1.000000
# 25     82  dalam konteks perusahaan  pada akhirnya sumber...      1  0.439024
# 26     40  perspektif utama sistem organisasi   pengelola...      3  0.800000
# 27      4                   manajemen proyek perangkat lunak      0  0.750000
# 28     22  melalui mata kuliah ini mahasiswa mampu memaha...      1  0.590909
# 29     18  mahasiswa mampu memahami teknik manajemen proy...      2  0.555556
# ...   ...                                                ...    ...       ...
# 1106    6  rekayasa perangkat lunak terdistribusi secara ...      0  0.500000
# 1107  293  rekayasa perangkat lunak beroperasi lebih seri...      1  0.409556
# 1108   58  untuk memahami konstruksi utama teori rekayasa...      2  0.413793
# 1109    5               ilmu informasi kuantum saya bagian        0  0.600000
# 1110  249  kursus ini adalah bagian terakhir dari tiga se...      1  0.453815
# 1111   27  model formal untuk kebisingan kuantum dan salu...      2  0.592593
# 1112    7  dasar pemikiran komputasi data sains dengan py...      0  0.857143
# 1113  179  kita hidup di era akses data yang belum pernah...      1  0.340782
# 1114   27  bagaimana menggunakan komputasi untuk membantu...      2  0.370370
# 1115    8  komputasi mobile dengan prinsip prinsip penemu...      0  0.750000
# 1116  190  belajar untuk menggunakan penemu aplikasi alat...      1  0.410526
# 1117   32  bagaimana merancang dan membuat aplikasi selul...      2  0.437500
# 1118    7  informatika kesehatan global untuk meningkatka...      0  0.428571
# 1119  373  penyakit tidak memiliki rasa hormat untuk perb...      1  0.426273
# 1120   17  beban kesehatan global n merancang pemikiran n...      2  0.705882
# 1121    5               ilmu informasi kuantum saya bagian        0  0.600000
# 1122  233  kursus ini adalah bagian dari tiga seri kursus...      1  0.459227
# 1123    7  mekanika kuantum pengukuran kuantum perhitunga...      2  0.428571
# 1124    8  keindahan dan sukacita komputasi prinsip prins...      0  0.875000
# 1125  235  temukan ide ide besar dan praktik berpikir dal...      1  0.404255
# 1126   48  dasar dasar pemrograman komputer menggunakan s...      2  0.479167
# 1127    2                                kriptografi kuantum      0  0.000000
# 1128  147  bagaimana anda bisa menceritakan rahasia ketik...      1  0.346939
# 1129   36  ide ide dasar dari kriptografi kuantum konsep ...      2  0.638889
# 1130    6  pemrograman untuk semua orang pengantar pemrog...      0  0.500000
# 1131  170  kursus ini adalah bagian dari gfa akademi maha...      1  0.335294
# 1132   34  apa yang seorang ilmuwan komputer tidak melaku...      2  0.558824
# 1133    5        algoritma terdistribusi yang andal bagian        0  0.200000
# 1134  165  kursus ini adalah kursus pertama dalam rangkai...      1  0.436364
# 1135   53  event driven concurrent programming dari distr...      2  0.547170
#
#          propn  subyek     takso    adalah  adalah bagian      akan  \
# 0     0.166667       0  0.000000  0.000000       0.000000  0.000000
# 1     0.019608       1  0.019608  0.160514       0.000000  0.000000
# 2     0.222222       0  0.222222  0.000000       0.000000  0.000000
# 3     0.115385       0  0.000000  0.000000       0.000000  0.000000
# 4     0.000000       0  0.000000  0.000000       0.000000  0.000000
# 5     0.058140       1  0.023256  0.000000       0.000000  0.000000
# 6     0.083333       0  0.000000  0.000000       0.000000  0.000000
# 7     0.666667       0  0.166667  0.000000       0.000000  0.000000
# 8     0.090909       1  0.000000  0.000000       0.000000  0.159989
# 9     0.285714       1  0.000000  0.000000       0.000000  0.000000
# 10    0.500000       0  0.000000  0.000000       0.000000  0.000000
# 11    0.000000       0  0.000000  0.000000       0.000000  0.000000
# 12    0.000000       1  0.000000  0.000000       0.000000  0.174750
# 13    0.000000       1  0.095238  0.000000       0.000000  0.000000
# 14    0.019231       1  0.000000  0.000000       0.000000  0.000000
# 15    0.000000       0  0.000000  0.000000       0.000000  0.000000
# 16    0.084211       1  0.010526  0.000000       0.000000  0.000000
# 17    0.122137       1  0.145038  0.000000       0.000000  0.000000
# 18    0.104167       0  0.000000  0.000000       0.000000  0.000000
# 19    1.000000       0  0.000000  0.000000       0.000000  0.000000
# 20    0.046296       0  0.009259  0.196649       0.000000  0.000000
# 21    0.000000       0  0.000000  0.000000       0.000000  0.000000
# 22    0.000000       1  0.028571  0.000000       0.000000  0.175163
# 23    0.000000       0  0.000000  0.000000       0.000000  0.000000
#
...      0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 1113     ...      0.000000  0.000000  0.000000  0.121473  0.000000  0.000000
# 1114     ...      0.000000  0.000000  0.000000  0.196361  0.000000  0.000000
# 1115     ...      0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 1116     ...      0.000000  0.000000  0.000000  0.119671  0.000000  0.000000
# 1117     ...      0.000000  0.000000  0.000000  0.124389  0.000000  0.000000
# 1118     ...      0.000000  0.000000  0.000000  0.402645  0.000000  0.000000
# 1119     ...      0.104358  0.000000  0.000000  0.146894  0.000000  0.000000
# 1120     ...      0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 1121     ...      0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 1122     ...      0.000000  0.000000  0.000000  0.110686  0.000000  0.000000
# 1123     ...      0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 1124     ...      0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 1125     ...      0.000000  0.115531  0.000000  0.112328  0.000000  0.000000
# 1126     ...      0.000000  0.000000  0.000000  0.106168  0.000000  0.000000
# 1127     ...      0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 1128     ...      0.000000  0.000000  0.131181  0.128088  0.000000  0.000000
# 1129     ...      0.000000  0.000000  0.237512  0.097185  0.000000  0.000000
# 1130     ...      0.000000  0.000000  0.000000  0.221637  0.000000  0.000000
# 1131     ...      0.000000  0.000000  0.000000  0.120556  0.000000  0.000000
# 1132     ...      0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 1133     ...      0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 1134     ...      0.000000  0.000000  0.137508  0.118079  0.000000  0.000000
# 1135     ...      0.000000  0.000000  0.000000  0.135747  0.000000  0.000000
#
#       web  windows      yang  yang lebih
# 0     0.0      0.0  0.000000    0.000000
# 1     0.0      0.0  0.107665    0.000000
# 2     0.0      0.0  0.000000    0.000000
# 3     0.0      0.0  0.000000    0.000000
# 4     0.0      0.0  0.000000    0.000000
# 5     0.0      0.0  0.087035    0.000000
# 6     0.0      0.0  0.000000    0.000000
# 7     0.0      0.0  0.000000    0.000000
# 8     0.0      0.0  0.267831    0.475063
# 9     0.0      0.0  0.000000    0.000000
# 10    0.0      0.0  0.000000    0.000000
# 11    0.0      0.0  0.000000    0.000000
# 12    0.0      0.0  0.139398    0.000000
# 13    0.0      0.0  0.000000    0.000000
# 14    0.0      0.0  0.128837    0.000000
# 15    0.0      0.0  0.000000    0.000000
# 16    0.0      0.0  0.142260    0.184721
# 17    0.0      0.0  0.179117    0.000000
# 18    0.0      0.0  0.000000    0.000000
# 19    0.0      0.0  0.000000    0.000000
# 20    0.0      0.0  0.185902    0.000000
# 21    0.0      0.0  0.000000    0.000000
# 22    0.0      0.0  0.243111    0.000000
# 23    0.0      0.0  0.000000    0.000000
# 24    0.0      0.0  0.000000    0.000000
# 25    0.0      0.0  0.149019    0.000000
# 26    0.0      0.0  0.000000    0.000000
# 27    0.0      0.0  0.000000    0.000000
# 28    0.0      0.0  0.000000    0.000000
# 29    0.0      0.0  0.000000    0.000000
# ...   ...      ...       ...         ...
# 1106  0.0      0.0  0.000000    0.000000
# 1107  0.0      0.0  0.132966    0.000000
# 1108  0.0      0.0  0.187661    0.000000
# 1109  0.0      0.0  0.000000    0.000000
# 1110  0.0      0.0  0.115014    0.000000
# 1111  0.0      0.0  0.000000    0.000000
# 1112  0.0      0.0  0.000000    0.000000
# 1113  0.0      0.0  0.176939    0.000000
# 1114  0.0      0.0  0.000000    0.000000
# 1115  0.0      0.0  0.000000    0.000000
# 1116  0.0      0.0  0.125952    0.106117
# 1117  0.0      0.0  0.000000    0.000000
# 1118  0.0      0.0  0.000000    0.000000
# 1119  0.0      0.0  0.147359    0.095344
# 1120  0.0      0.0  0.000000    0.000000
# 1121  0.0      0.0  0.000000    0.000000
# 1122  0.0      0.0  0.116496    0.000000
# 1123  0.0      0.0  0.000000    0.000000
# 1124  0.0      0.0  0.000000    0.000000
# 1125  0.0      0.0  0.168341    0.259915
# 1126  0.0      0.0  0.189193    0.000000
# 1127  0.0      0.0  0.000000    0.000000
# 1128  0.0      0.0  0.147417    0.000000
# 1129  0.0      0.0  0.000000    0.000000
# 1130  0.0      0.0  0.000000    0.000000
# 1131  0.0      0.0  0.199676    0.132922
# 1132  0.0      0.0  0.109404    0.000000
# 1133  0.0      0.0  0.344614    0.000000
# 1134  0.0      0.0  0.165323    0.000000
# 1135  0.0      0.0  0.241903    0.000000
#
# [1136 rows x 157 columns]

# %% [markdown]
# # Prepare Dataset

# %%
#Bisa dipakai untuk klasifikasi dengan crossval
from sklearn.model_selection import cross_validate

x=deskr_p.drop(columns=['label', 'kalimat'])
y=deskr_p['label']

# %%
#Split Dataset untuk klasifikasi tanpa crossval
from sklearn.model_selection import train_test_split

# data_train, data_test = train_test_split(y, shuffle=False)

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.33, random_state=0, stratify=y) #stratify agar pembagian tiap kelas merata

# %%
#untuk crossval
np.save("data/data_split/X.npy", x)
np.save("data/data_split/y.npy", y)
#non-crossval
np.save("data/data_split/X_train.npy", X_train)
np.save("data/data_split/y_train.npy", y_train)
np.save("data/data_split/X_test.npy", X_test)
np.save("data/data_split/y_test.npy", y_test)

# %% [markdown]
# # OverSampling dengan SMOTE

# %%
from imblearn.over_sampling import SMOTE

sm = SMOTE(random_state=0)
ftr_smt, cls_smt = sm.fit_sample(X_train, y_train)

# %%
sm
# Out:
# SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=0, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')

# %%
from collections import Counter
print('Original dataset shape %s' % Counter(y_train))
print('SMOTE dataset shape %s' % Counter(cls_smt))
# Out:
# Original dataset shape Counter({0: 252, 1: 251, 2: 245, 3: 13})
# SMOTE dataset shape Counter({0: 252, 1: 252, 2: 252, 3: 252})

# %%
np.save('data/oversampling/ftr_smote.npy', ftr_smt)
np.save('data/oversampling/cls_smote.npy', cls_smt)

# %% [markdown]
# # Oversampling dengan ADASYN

# %%
from imblearn.over_sampling import ADASYN

ada = ADASYN(sampling_strategy='minority',random_state=0)
ftr_ada, cls_ada = ada.fit_resample(X_train, y_train)

# %%
ada
# Out:
# ADASYN(n_jobs=1, n_neighbors=5, random_state=0, ratio=None,
#     sampling_strategy='minority')

# %%
from collections import Counter
print('Original dataset shape %s' % Counter(y_train))
print('Adasyn dataset shape %s' % Counter(cls_ada))
# Out:
# Original dataset shape Counter({0: 252, 1: 251, 2: 245, 3: 13})
# Adasyn dataset shape Counter({0: 252, 1: 251, 3: 247, 2: 245})

# %%
np.save('data/oversampling/ftr_adasyn.npy', ftr_ada)
np.save('data/oversampling/cls_adasyn.npy', cls_ada)
